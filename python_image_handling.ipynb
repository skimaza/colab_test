# %% [markdown]
# <a href="https://colab.research.google.com/github/skimaza/colab_test/blob/main/python_image_handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls sample_data
# Out:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %%
# !ls drive/MyDrive/aSSIST/images
# Out:
# 1024px-Iris_virginica.jpg     800px-Kosaciec_szczecinkowaty_Iris_setosa.jpg
# 1280px-Iris_versicolor_3.jpg  yacht_bw.png

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

# %%
from PIL import Image

# %% [markdown]
# # OpenCV로 읽기

# %% [markdown]
# # 디폴트는 RGB 컬러로 취급

# %%
img_rgb = cv.imread('drive/MyDrive/aSSIST/images/yacht_bw.png')

# %%
plt.imshow(img_rgb)

# %%
img_rgb.max(), img_rgb.min()
# Out:
# (237, 2)

# %%
img_rgb.shape
# Out:
# (512, 512, 3)

# %% [markdown]
# 흑백으로 읽기

# %%
img_bw = cv.imread('drive/MyDrive/aSSIST/images/yacht_bw.png', cv.IMREAD_GRAYSCALE)

# %%
img_bw.max(), img_bw.min()
# Out:
# (237, 2)

# %%
img_bw.shape
# Out:
# (512, 512)

# %%
plt.imshow(img_bw) # default는 viridis
plt.colorbar()

# %%
plt.imshow(img_bw, 'gray')
plt.colorbar()

# %% [markdown]
# # 좌표계에 주의
# 수직축이 첫번째 dimension, 수평축이 두번째 dimension
# 세번째 dimension은 optional (RGB 색상)

# %%
img_bw[300:302, 300:302], img_bw[300, 300]
# Out:
# (array([[53, 69],
#         [38, 47]], dtype=uint8), 53)

# %%
print('img_bw[300:400, 300:400]')
plt.imshow(img_bw[300:400, 300:400], 'gray')
#plt.colorbar()
plt.show()
print('img_bw[350:400, 300:400]')
plt.imshow(img_bw[350:400, 300:400], 'gray')
#plt.colorbar()
plt.show()
print('img_bw[300:400, 300:350]')
plt.imshow(img_bw[300:400, 300:350], 'gray')
#plt.colorbar()
plt.show()
# Out:
# img_bw[300:400, 300:400]
# img_bw[350:400, 300:400]
# img_bw[300:400, 300:350]
